# %%
import pandas as pd

# %%
path = r"C:\Users\h\OneDrive\Desktop\Machine-Learning-Algorithms\Supervised Learning\Logistic Regression\loan_approval\data\raw_data/loan_data.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001001    Male      No          0      Graduate            No
# 1  LP001002    Male     Yes          1      Graduate            No
# 2  LP001003    Male     Yes          0      Graduate           Yes
# 3  LP001004    Male     Yes          0  Not Graduate            No
# 4  LP001005  Female      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0       128.0             360.0
# 1             4583               1508       128.0             360.0
# 2             3000                  0        66.0             360.0
# 3             2583               2358         NaN             360.0
# 4             6000                  0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0     Semiurban           Y

# %%
print(f"Row X Columns: {df.shape}")
# Out:
# Row X Columns: (25, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            25 non-null     object
#  1   Gender             24 non-null     object
#  2   Married            25 non-null     object
#  3   Dependents         24 non-null     object
#  4   Education          25 non-null     object
#  5   Self_Employed      24 non-null     object
#  6   ApplicantIncome    25 non-null     int64
#  7   CoapplicantIncome  25 non-null     int64
#  8   LoanAmount         23 non-null     float64
#  9   Loan_Amount_Term   24 non-null     float64
#  10  Credit_History     24 non-null     float64
#  11  Property_Area      25 non-null     object
#  12  Loan_Status        25 non-null     object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 2.7+ KB

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               1
# Married              0
# Dependents           1
# Education            0
# Self_Employed        1
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           2
# Loan_Amount_Term     1
# Credit_History       1
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.shape
# Out:
# (25, 13)

# %%
df["Loan_Status"].value_counts().plot(kind="bar",color=["#AC0B69", "#1fb3c7"], rot=0)
# Out:
# <Axes: xlabel='Loan_Status'>
